# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
sns.pairplot(df,hue='Outcome',palette='husl')

# %%
sns.countplot(x='Outcome',data=df)
plt.show()

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df['Pregnancies'].value_counts()
# Out:
# Pregnancies
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 17      1
# 15      1
# Name: count, dtype: int64

# %%
sns.countplot(x='Pregnancies',data=df,hue='Outcome')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='count'>

# %%
def plot_graph(df):
  plt=sns.histplot(df,kde=True)
  plt.set_title(df.name + 'Distribution')
  plt.set_xlabel(df.name + 'class')
  plt.set_ylabel('Count')

# %%
plot_graph(df['Glucose'])

# %%
df[df.Outcome == False]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
def plot_graph_1(df,column):
  plt=sns.histplot(df[df.Outcome == False][column.name],color='green',label='Non-diabetic')
  plt=sns.histplot(df[df.Outcome == True][column.name],color='red',label='diabetic')
  plt.set_title('Distribution of'+column.name)
  plt.set_xlabel(column.name)
  plt.set_ylabel('counts')
  plt.axes.legend(loc=0)

# %%
plot_graph_1(df,df.Glucose)

# %%
plot_graph(df['BloodPressure'])

# %%
plot_graph_1(df,df['BloodPressure'])

# %%
plot_graph(df['SkinThickness'])

# %%
plot_graph_1(df,df['SkinThickness'])

# %%
plot_graph(df['Insulin'])

# %%
plot_graph_1(df,df['Insulin'])

# %%
plot_graph(df['BMI'])

# %%
plot_graph_1(df,df['BMI'])

# %%
plot_graph(df['DiabetesPedigreeFunction'])

# %%
plot_graph_1(df,df['DiabetesPedigreeFunction'])

# %%
plot_graph(df['Age'])

# %%
plot_graph_1(df,df['Age'])

# %%
sns.heatmap(df.corr(),fmt='.1f',annot=True,cmap='GnBu')
plt.title("Correlation map")
plt.show()
